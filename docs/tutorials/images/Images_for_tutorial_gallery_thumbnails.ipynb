# %% [markdown]
# ## This notebook exists soley for the purpose of creating images for the tutorial gallery (when it does not automatically work directly from the relevant notebook)

# %% [markdown]
# [Block_Bootstrapping.ipynb](../Block_Bootstrapping.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing time series data with multiple colored lines and shaded confidence intervals demonstrating block bootstrapping technique for temporal data analysis](block_bootstrapping_thumbnail.png)

# %% [markdown]
# [Isotonic_Regression_And_Reliability_Diagrams.ipynb](../Isotonic_Regression_And_Reliability_Diagrams.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing a reliability diagram with forecast probability on x-axis and observed frequency on y-axis, demonstrating isotonic regression for forecast calibration](isotonic_regression_thumbnail.png)

# %% [markdown]
# [Binary_Contingency_Scores.ipynb](../Binary_Contingency_Scores.ipynb) tutorial gallery thumbnail(below)

# %% [markdown]
# ![Tutorial preview showing a 2x2 contingency table matrix with hit rate, false alarm rate, and related binary classification metrics for forecast verification](binary_contingency_thumbnail.png)

# %% [markdown]
# [Q-Q_plots.ipynb](../Q-Q_plots.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing quantile-quantile plot comparing forecast and observation distributions with points along a diagonal reference line to assess distributional similarity](qq_thumbnail.png)

# %% [markdown]
# [Angular_data.ipynb](../Angular_data.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing circular plot or wind rose diagram demonstrating scoring methods for angular or directional data such as wind direction](angular_data_thumbnail.png)

# %% [markdown]
# [Dimension_Handling.ipynb](../Dimension_Handling.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing multidimensional data visualization demonstrating how the scores library handles different array dimensions in xarray datasets](dimension_handling_thumbnail.png)

# %% [markdown]
# [NSE.ipynb](../NSE.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing scatter plot with forecast vs observation data demonstrating Nash-Sutcliffe Efficiency (NSE) score calculation for hydrological and continuous forecast verification](NSE_thumbnail.png)

# %% [markdown]
# [Quantile_Loss.ipynb](../Quantile_Loss.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing quantile forecast evaluation with plots demonstrating quantile loss calculation for probabilistic forecast verification at different probability levels](quantile_loss_thumbnail.png)

# %% [markdown]
# [Threshold_Weighted_Scores.ipynb](../Threshold_Weighted_Scores.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing threshold-weighted scoring visualization where different forecast value ranges are weighted differently for evaluating forecasts focused on specific critical thresholds](threshold_weighted_scores_thumbnail.png)

# %% [markdown]
# [Threshold_Weighted_CRPS_for_Ensembles.ipynb](../Threshold_Weighted_CRPS_for_Ensembles.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing ensemble forecast visualization with multiple forecast members demonstrating threshold-weighted Continuous Ranked Probability Score (CRPS) for ensemble verification emphasizing extreme values](twCRPS_for_ensembles_thumbnail.png)

# %% [markdown]
# [Brier_Score.ipynb](../Brier_Score.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing probability forecast verification with Brier score calculation for binary event predictions assessing the accuracy of probabilistic forecasts](brier_thumbnail.png)

# %% [markdown]
# [Quantile_Interval_And_Interval_Score.ipynb](../Quantile_Interval_And_Interval_Score.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing interval forecasts with upper and lower quantile bounds and interval score calculation for evaluating prediction interval coverage and sharpness](quantile_interval_score_and_interval_score_thumbnail.png)

# %% [markdown]
# [Fractions_Skill_Score.ipynb](../Fractions_Skill_Score.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing spatial field comparison with grid-based forecast and observation fields demonstrating Fractions Skill Score (FSS) for neighborhood-based spatial verification](fss_thumbnail.png)

# %% [markdown]
# [Diebold_Mariano_Test_Statistic.ipynb](../Diebold_Mariano_Test_Statistic.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Tutorial preview showing statistical comparison of forecast accuracy between two forecasting systems using the Diebold-Mariano test statistic for time series forecast evaluation](diebold_mariano_thumbnail.png)
